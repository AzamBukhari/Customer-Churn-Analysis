# %% [markdown]
# ![Telco Customer Churn!](Customer.png "Telco Customer Churn By Azam  Bukhari")

# %% [markdown]
# # About Author
# - Project: Telecom Customer Churn Data
# - Author: Azam Bukhari
# - Code Submission Date: 21-03-2023
# - Author's Contact Info:\
# [Email](azam.bukhari@gmail.com)\
# [Github](https://github.com/AzamBukhari)\
# [kaggle](https://www.kaggle.com/azambukhari)\
# [Linkedin](https://www.linkedin.com/in/azambukhari)\
# [twitter](https://twitter.com/AzamBukhari1)\
# [Medium](https://medium.com/@azam.bukhari)

# %% [markdown]
# # About Data
# - Data: A fictional telco company that provided home phone and Internet services to 7043 customers in California, USA in Q3 (Quarter-3).
# - Data can be downloadd from this link: 🔗 [*link*](https://www.kaggle.com/datasets/yeanzc/telco-customer-churn-ibm-dataset)
# ## Task:
# We intend to conduct an Exploratory Data Analysis (EDA) on the given dataset. The EDA will serve as the basis for the necessary Data Wrangling activities to be carried out for the purposes of data cleaning and normalization.\
# During the coding process, we will document our observations. Ultimately, we will produce a summary and draw conclusions from our findings.
#
# ## Objectives:
# 1. The primary aim of this project is to conduct a thorough analysis of the dataset to identify significant insights about churning customers (refer to churn meaning in the glossary below).
# 2. Within a telecommunications company, there are expenses related to promotions, known as Acquisition Cost and Retention Cost.
# 3. The Acquisition Cost pertains to the amount required to acquire new customers while Retention Cost relates to the expenses involved in keeping the company's existing customers satisfied and loyal.
#
# We will perform EDA on the subject dataset and try to observe and study the dynamics involved in churn transformation.
#
#
# ## Kernel Version Used:
# - Python 3.11.1

# %% [markdown]
# ---

# %% [markdown]
# # Glossary / Data Dictionary / Important Terms
#
# Churn: Churn may also apply to the number of subscribers who cancel or don't renew a subscription.
#
# Churn Rate: Churn rate is defined as percentage of lost customers or revenue in a certain time period
#
# CustomerID: A unique ID that identifies each customer.
#
# Count: A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
#
# Country: The country of the customer’s primary residence.
#
# State: The state of the customer’s primary residence.
#
# City: The city of the customer’s primary residence.
#
# Zip Code: The zip code of the customer’s primary residence.
#
# Lat Long: The combined latitude and longitude of the customer’s primary residence.
#
# Latitude: The latitude of the customer’s primary residence.
#
# Longitude: The longitude of the customer’s primary residence.
#
# Gender: The customer’s gender: Male, Female
#
# Senior Citizen: Indicates if the customer is 65 or older: Yes, No
#
# Partner: Indicate if the customer has a partner: Yes, No
#
# Dependents: Indicates if the customer lives with any dependents: Yes, No. Dependents could be children, parents, grandparents, etc.
#
# Tenure Months: Indicates the total amount of months that the customer has been with the company by the end of the quarter specified above.
#
# Phone Service: Indicates if the customer subscribes to home phone service with the company: Yes, No
#
# Multiple Lines: Indicates if the customer subscribes to multiple telephone lines with the company: Yes, No
#
# Internet Service: Indicates if the customer subscribes to Internet service with the company: No, DSL, Fiber Optic, Cable.
#
# Online Security: Indicates if the customer subscribes to an additional online security service provided by the company: Yes, No
#
# Online Backup: Indicates if the customer subscribes to an additional online backup service provided by the company: Yes, No
#
# Device Protection: Indicates if the customer subscribes to an additional device protection plan for their Internet equipment provided by the company: Yes, No
#
# Tech Support: Indicates if the customer subscribes to an additional technical support plan from the company with reduced wait times: Yes, No
#
# Streaming TV: Indicates if the customer uses their Internet service to stream television programing from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# Streaming Movies: Indicates if the customer uses their Internet service to stream movies from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# Contract: Indicates the customer’s current contract type: Month-to-Month, One Year, Two Year.
#
# Paperless Billing: Indicates if the customer has chosen paperless billing: Yes, No
#
# Payment Method: Indicates how the customer pays their bill: Bank Withdrawal, Credit Card, Mailed Check
#
# Monthly Charge: Indicates the customer’s current total monthly charge for all their services from the company.
#
# Total Charges: Indicates the customer’s total charges, calculated to the end of the quarter specified above.
#
# Churn Label: Yes = the customer left the company this quarter. No = the customer remained with the company. Directly related to Churn Value.
#
# Churn Value: 1 = the customer left the company this quarter. 0 = the customer remained with the company. Directly related to Churn Label.
#
# Churn Score: A value from 0-100 that is calculated using the predictive tool IBM SPSS Modeler. The model incorporates multiple factors known to cause churn. The higher the score, the more likely the customer will churn.
#
# CLTV: Customer Lifetime Value. A predicted CLTV is calculated using corporate formulas and existing data. The higher the value, the more valuable the customer. High value customers should be monitored for churn.
#
# Churn Reason: A customer’s specific reason for leaving the company. Directly related to Churn Category.

# %% [markdown]
# # *Import Libraries*
# - We will use the follwoing libraries
# 1. **Pandas**: Data manipulation, exploration and analysis library.
# 2. **Numpy**: Numerical computing library.
# 3. **Matplotlib**: Data visualization library.
# 4. **Seaborn**: Statistical data visualization library.
# 5. **Scipy**:  To provide a comprehensive set of numerical algorithms and tools for scientific computing in Python.
# 6. **Folium**: Folium is a Python library used for visualizing geospatial data

# %%
import pandas as pd
import numpy as np

# visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# for scientific and statistical computing
import scipy as sp
#to visualise geo spatial data
import folium

# %% [markdown]
# # Data Loading, Exploration & Wrangling
#
# We will proceed as follow:
# 1. Load the xlsx file with the pandas
# 2. Creating the dataframe and understanding the data present in the dataset
# 3. Dealing with the missing data and the incorrect records

# %%
# Load dataset Telco_Churn
df = pd.read_excel("Telco_customer_churn.xlsx")

# %% [markdown]
# ### Analysing & describing the dataset
#
# This code snippet helps us get a complete overview of your data by adjusting a key display setting in Pandas.
# By setting the option to show all columns, you can ensure that no valuable information is overlooked when working with dataframes.
# Whether you're exploring data, conducting analyses or simply trying to get a better sense of your data, this simple line of code can make a big difference.

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Get a sneak peek of our data
# With just a single line of code! Quickly view the top rows of your dataset to get a sense of what you're working with, without having to scroll through the entire file.

# %%
#Note that the background_gradient() method returns the Styler object itself, so you can chain additional styling methods if you want. 
df.head(5).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_9c33f_row0_col1, #T_9c33f_row0_col5, #T_9c33f_row0_col7, #T_9c33f_row0_col13, #T_9c33f_row0_col26, #T_9c33f_row0_col29, #T_9c33f_row1_col1, #T_9c33f_row1_col13, #T_9c33f_row1_col29, #T_9c33f_row1_col30, #T_9c33f_row1_col31, #T_9c33f_row2_col1, #T_9c33f_row2_col29, #T_9c33f_row3_col1, #T_9c33f_row3_col8, #T_9c33f_row3_col29, #T_9c33f_row4_col1, #T_9c33f_row4_col29 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9c33f_row0_col8 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_9c33f_row0_col30, #T_9c33f_row2_col30 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_9c33f_row0_col31 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_9c33f_row1_col5, #T_9c33f_row1_col8 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_9c33f_row1_col7 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_9c33f_row1_col26 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_9c33f_row2_col5 {
# ...

# %% [markdown]
# ### View the shape of the dataset

# %%
# Use f-string formatting to display the number of rows and columns
output_str = f"Rows={df.shape[0]} Col={df.shape[1]}"

print(output_str)  # Output: Rows=3 Col=3
# Out:
# Rows=7043 Col=33

# %% [markdown]
# ### Observation Number 1
#
# Upon initial examination of the data, it has come to our attention that particular columns are causing redundancy within the dataset For Example:
#
# - Lat Long is prsenting the same information as Latitude and Longitude columns
# - Churn Label & Churn Value are both storing and presenting the same information in different formats
#
# We Can present the information stored in the customer’s current contract type: Month-to-Month, One Year, Two Year as:
#
# - Monthly
# - Annual
# - Biennial
#
# These columns may be purged at later stage of this analysis (if required)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %% [markdown]
# ### Descriptive Statistics
# We use descriptive statistics to summarize and understand the key features of dataset.

# %%
#Note that the background_gradient() method returns the Styler object itself, so you can chain additional styling methods if you want. 
df.describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_63218_row0_col0, #T_63218_row0_col2, #T_63218_row0_col3, #T_63218_row0_col4, #T_63218_row0_col5, #T_63218_row0_col6, #T_63218_row0_col7, #T_63218_row0_col8, #T_63218_row7_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_63218_row0_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_63218_row1_col0, #T_63218_row1_col3, #T_63218_row1_col6, #T_63218_row2_col0, #T_63218_row2_col1, #T_63218_row2_col2, #T_63218_row2_col4, #T_63218_row2_col5, #T_63218_row2_col6, #T_63218_row2_col7, #T_63218_row2_col8, #T_63218_row3_col0, #T_63218_row3_col3, #T_63218_row3_col4, #T_63218_row3_col5, #T_63218_row3_col6, #T_63218_row3_col7, #T_63218_row4_col0, #T_63218_row4_col3, #T_63218_row4_col4, #T_63218_row4_col5, #T_63218_row4_col6, #T_63218_row5_col0, #T_63218_row5_col3, #T_63218_row5_col6, #T_63218_row6_col0, #T_63218_row6_col3, #T_63218_row6_col6, #T_63218_row7_col0, #T_63218_row7_col3, #T_63218_row7_col6 {
#   background-color: #f7fbff;
# ...

# %% [markdown]
# ### Missing values in the data

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Churn Reason         5174
# Online Security         0
# CLTV                    0
# Churn Score             0
# Churn Value             0
# Churn Label             0
# Total Charges           0
# Monthly Charges         0
# Payment Method          0
# Paperless Billing       0
# Contract                0
# Streaming Movies        0
# Streaming TV            0
# Tech Support            0
# Device Protection       0
# Online Backup           0
# CustomerID              0
# Count                   0
# Multiple Lines          0
# Phone Service           0
# Tenure Months           0
# Dependents              0
# Partner                 0
# Senior Citizen          0
# Gender                  0
# Longitude               0
# Latitude                0
# Lat Long                0
# Zip Code                0
# City                    0
# State                   0
# Country                 0
# Internet Service        0
# dtype: int64

# %% [markdown]
# ## **Exploratory Analysis and Visualization**

# %%
#This code sets the default figure size for Matplotlib plots, 
# creates a heatmap using Seaborn to visualize null values in a 
# DataFrame, removes y-axis labels and the colorbar from the heatmap, 
# sets the color map to green, and adds a title to the plot indicating 
# that it shows missing null values in the DataFrame.
plt.rcParams['figure.figsize'] = (15,6)
sns.heatmap(df.isnull(),yticklabels = False, cbar = False , cmap = 'Greens')
plt.title("Missing null values")
# Out:
# Text(0.5, 1.0, 'Missing null values')

# %% [markdown]
# > **Figure-1:** Provide us the visual on the missing values in a dataframe 'df'.

# %%
# #### Get a clearer picture of missing data with this nifty code snippet! 
# See the percentage of null values in our dataset sorted in ascending order,
# making it easy to identify which features have the most missing data.
missing_percentage = (df.isnull().sum().sort_values(ascending = False)/len(df))*100
missing_percentage
# Out:
# Churn Reason         73.463013
# Online Security       0.000000
# CLTV                  0.000000
# Churn Score           0.000000
# Churn Value           0.000000
# Churn Label           0.000000
# Total Charges         0.000000
# Monthly Charges       0.000000
# Payment Method        0.000000
# Paperless Billing     0.000000
# Contract              0.000000
# Streaming Movies      0.000000
# Streaming TV          0.000000
# Tech Support          0.000000
# Device Protection     0.000000
# Online Backup         0.000000
# CustomerID            0.000000
# Count                 0.000000
# Multiple Lines        0.000000
# Phone Service         0.000000
# Tenure Months         0.000000
# Dependents            0.000000
# Partner               0.000000
# Senior Citizen        0.000000
# Gender                0.000000
# Longitude             0.000000
# Latitude              0.000000
# Lat Long              0.000000
# Zip Code              0.000000
# City                  0.000000
# ...

# %% [markdown]
# ### Observation Number 2
#
# > Dealing with the null values
#
#
# - Only one column has the highest percentage of null values:\
#  *Churn Reason*
#
# Customer feedback is always a high valued information. But due to high percentage of null values in it, we decide to drop this column
#
# Also at this stage we will drop the attaributes carrying redundant information. As mentoned in Observation Number 1 earlier:
#
# - Lat Long
# - Churn Value

# %%
#droping Lat Long attribute
df.drop('Churn Reason', axis=1, inplace=True)

# %%
#droping Lat Long attribute
df.drop('Lat Long', axis=1, inplace=True)

# %%
##Churn Value
df.drop('Churn Value', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Latitude           7043 non-null   float64
#  7   Longitude          7043 non-null   float64
#  8   Gender             7043 non-null   object
#  9   Senior Citizen     7043 non-null   object
#  10  Partner            7043 non-null   object
#  11  Dependents         7043 non-null   object
#  12  Tenure Months      7043 non-null   int64
#  13  Phone Service      7043 non-null   object
#  14  Multiple Lines     7043 non-null   object
#  15  Internet Service   7043 non-null   object
# ...

# %% [markdown]
# ### Observation Number 3
#
# > Dealing with the column names with spaces in between them
#
#
# - Athough its not a critical issue, but for the ease of coding & readability. We will rename the following columns to remove any extra space in column names:
# 1. Zip Code --> zip_code
# 2. Senior Citizen --> senior_citizen
# 3. Tenure Months --> tenure_months
# 4. Phone Service --> phone_service
# 5. Multiple Lines --> multiple_lines
# 6. Internet Service --> internet_service
# 7. Online Security --> online_security
# 8. Online Backup --> online_backup
# 9. Device Protection --> device_protection
# 10. Tech Support --> tech_support
# 11. Streaming TV --> streaming_tv
# 12. Streaming Movies --> streaming_movies
# 13. Paperless Billing --> paperless_billing
# 14. Payment Method --> payment_method
# 15. Monthly Charges --> monthly_charges
# 16. Total Charges --> total_charges
# 17. Churn Label --> churn_label
# 18. Churn Score --> churn_score

# %%
# rename columns 
df = df.rename(columns={'Zip Code': 'zip_code', 'Senior Citizen': 'senior_citizen', 'Tenure Months': 'tenure_months', 'Phone Service': 'phone_service', 'Multiple Lines': 'multiple_lines', 'Internet Service': 'internet_service','Online Security': 'online_security', 'Online Backup': 'online_backup', 'Device Protection': 'device_protection', 'Tech Support': 'tech_support', 'Streaming TV': 'streaming_tv', 'Streaming Movies': 'streaming_movies', 'Payment Method': 'payment_method', 'Monthly Charges': 'monthly_charges', 'Total Charges': 'total_charges','Churn Label': 'churn_label','Churn Score': 'churn_score'})
print(df.columns)
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'zip_code',
#        'Latitude', 'Longitude', 'Gender', 'senior_citizen', 'Partner',
#        'Dependents', 'tenure_months', 'phone_service', 'multiple_lines',
#        'internet_service', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
#        'Contract', 'Paperless Billing', 'payment_method', 'monthly_charges',
#        'total_charges', 'churn_label', 'churn_score', 'CLTV'],
#       dtype='object')

# %%
##have a view of refreshed dataset again
df.isnull().sum().sort_values(ascending = False)
# Out:
# CustomerID           0
# Count                0
# churn_score          0
# churn_label          0
# total_charges        0
# monthly_charges      0
# payment_method       0
# Paperless Billing    0
# Contract             0
# streaming_movies     0
# streaming_tv         0
# tech_support         0
# device_protection    0
# online_backup        0
# online_security      0
# internet_service     0
# multiple_lines       0
# phone_service        0
# tenure_months        0
# Dependents           0
# Partner              0
# senior_citizen       0
# Gender               0
# Longitude            0
# Latitude             0
# zip_code             0
# City                 0
# State                0
# Country              0
# CLTV                 0
# dtype: int64

# %% [markdown]
# ### Getting Visual for any Outlier (if any) in the monthly_charges column

# %%
import seaborn as sns
sns.boxplot(data=df, y='monthly_charges', x='Gender', hue ='Gender')
# Out:
# <AxesSubplot: xlabel='Gender', ylabel='monthly_charges'>

# %% [markdown]
# > **Figure-2:** We used box-plots to visually detect any outlier in the monthly_charges column. However we found that data between males & females is equally distributes and clean

# %% [markdown]
# ### Observation Number 4
#
# > We have a clean data set
#
# > Next, Find duplications and Analyse them if its a valid DUPLICATION

# %%
df.duplicated().any()
# Out:
# False

# %%
df.columns.unique()
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'zip_code',
#        'Latitude', 'Longitude', 'Gender', 'senior_citizen', 'Partner',
#        'Dependents', 'tenure_months', 'phone_service', 'multiple_lines',
#        'internet_service', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
#        'Contract', 'Paperless Billing', 'payment_method', 'monthly_charges',
#        'total_charges', 'churn_label', 'churn_score', 'CLTV'],
#       dtype='object')

# %%
any_duplicates = df.duplicated(subset=['CustomerID', 'Count', 'Country', 'State', 'City', 'zip_code',
       'Latitude', 'Longitude', 'Gender', 'senior_citizen', 'Partner',
       'Dependents', 'tenure_months', 'phone_service', 'multiple_lines',
       'internet_service', 'online_security', 'online_backup',
       'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
       'Contract', 'Paperless Billing', 'payment_method', 'monthly_charges',
       'total_charges', 'churn_label', 'churn_score', 'CLTV']).any()

# %%
any_duplicates
# Out:
# False

# %%
boolean = df['CustomerID'].duplicated().any()
boolean
# Out:
# False

# %% [markdown]
# ### Observation Number 5
#
# > No duplication found in the dataset

# %%
#The code df.describe().style.background_gradient(cmap='Blues')
# applies a background color gradient to a pandas DataFrame
df.describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_5c6fe_row0_col0, #T_5c6fe_row0_col2, #T_5c6fe_row0_col3, #T_5c6fe_row0_col4, #T_5c6fe_row0_col5, #T_5c6fe_row0_col6, #T_5c6fe_row0_col7, #T_5c6fe_row7_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5c6fe_row0_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_5c6fe_row1_col0, #T_5c6fe_row1_col3, #T_5c6fe_row2_col0, #T_5c6fe_row2_col1, #T_5c6fe_row2_col2, #T_5c6fe_row2_col4, #T_5c6fe_row2_col5, #T_5c6fe_row2_col6, #T_5c6fe_row2_col7, #T_5c6fe_row3_col0, #T_5c6fe_row3_col3, #T_5c6fe_row3_col4, #T_5c6fe_row3_col5, #T_5c6fe_row3_col6, #T_5c6fe_row4_col0, #T_5c6fe_row4_col3, #T_5c6fe_row4_col4, #T_5c6fe_row4_col5, #T_5c6fe_row5_col0, #T_5c6fe_row5_col3, #T_5c6fe_row6_col0, #T_5c6fe_row6_col3, #T_5c6fe_row7_col0, #T_5c6fe_row7_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5c6fe_row1_col1, #T_5c6fe_row5_col1 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ### Now exploring Numeric columns/attributes of the dataset mainly:
# Monthly_Charges, CLTV, Tenure_Months, Churn_Score

# %% [markdown]
# > Let us check how numerical values are correlated ot each other

# %%
#checking the corrlation of all the attributes with target
plt.figure(figsize=(15, 6))
cmap = "PiYG"
heatmap=sns.heatmap(df.corr(),cmap=cmap, annot=True)
heatmap.set_title('Telco Data Correlation Heatmap', fontdict={'fontsize':12}, pad=12)
# Out:
# C:\Users\azamb\AppData\Local\Temp\ipykernel_14588\531103630.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap=sns.heatmap(df.corr(),cmap=cmap, annot=True)
# Text(0.5, 1.0, 'Telco Data Correlation Heatmap')

# %% [markdown]
# > **Figure-3:** Provide us the visual correlation among the numerical attributes of the dataset

# %% [markdown]
# ### Observation Number 6
#
# > The correlation plot procide us many insights as follow:
# 1. A strong correlation exist between Tenure_months and CLTV
# 2. Correaltion exist between monthky charges & Tenure months
# 3. Monthly charges also play a role in dictating the churn score of the customer

# %% [markdown]
# ### Distribution of numerical variables
# - Monthly_Charges, CLTV, Tenure_Months, Churn_Score

# %%
# Create a histogram of the price variable

plt.hist(df["Monthly_Charges"],bins=10,edgecolor='blue')
plt.xlabel("Monthly_Charges")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# > **Figure-4:** Histogram plot to check the normality and distribution of Monthly charges. Data does not look normal. To confirm our visualisation we will apply kolmogorov-Smirnov test. Since we have data values more than 5000

# %%
from scipy.stats import kstest, norm


# perform Kolmogorov-Smirnov test on the data_column column
stat, p = kstest(df['Monthly_Charges'], 'norm')

# print the test statistic and p-value
print('Kolmogorov-Smirnov Test Statistic = %.3f, p-value = %.3f' % (stat, p))
# Out:
# Kolmogorov-Smirnov Test Statistic = 1.000, p-value = 0.000

# %% [markdown]
# The Kolmogorov-Smirnov test resulted in a test statistic of 1.000, indicating that the two samples or distributions are completely different. The p-value of 0.000 provides strong evidence to reject the null hypothesis and conclude that the two samples are not from the same population.

# %%
plt.hist(df["CLTV"],bins=10,edgecolor='blue')
plt.xlabel("CLTV")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# > **Figure-5:** Histogram plot to check the normality and distribution of CLTV. Data does not look normal. To confirm our visualisation we will apply kolmogorov-Smirnov test. Since we have data values more than 5000

# %%
from scipy.stats import kstest, norm


# perform Kolmogorov-Smirnov test on the data_column column
stat, p = kstest(df['CLTV'], 'norm')

# print the test statistic and p-value
print('Kolmogorov-Smirnov Test Statistic = %.3f, p-value = %.3f' % (stat, p))
# Out:
# Kolmogorov-Smirnov Test Statistic = 1.000, p-value = 0.000

# %%
plt.hist(df["Tenure_Months"],bins=10,edgecolor='blue')
plt.xlabel("Tenure_Months")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# > **Figure-6:** Histogram plot to check the normality and distribution of Tenure Months. Data does not look normal. To confirm our visualisation we will apply kolmogorov-Smirnov test. Since we have data values more than 5000

# %%
#Tenure_Month
from scipy.stats import kstest, norm


# perform Kolmogorov-Smirnov test on the data_column column
stat, p = kstest(df['Tenure_Months'], 'norm')

# print the test statistic and p-value
print('Kolmogorov-Smirnov Test Statistic = %.3f, p-value = %.3f' % (stat, p))
# Out:
# Kolmogorov-Smirnov Test Statistic = 0.889, p-value = 0.000

# %%
plt.hist(df["Churn_Score"],bins=10,edgecolor='blue')
plt.xlabel("Churn_Score")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# > **Figure-7:** Histogram plot to check the normality and distribution of Churn Score.  Data does not look normal. To confirm our visualisation we will apply kolmogorov-Smirnov test. Since we have data values more than 5000

# %%
#Tenure_Month
from scipy.stats import kstest, norm


# perform Kolmogorov-Smirnov test on the data_column column
stat, p = kstest(df['Churn_Score'], 'norm')

# print the test statistic and p-value
print('Kolmogorov-Smirnov Test Statistic = %.3f, p-value = %.3f' % (stat, p))
# Out:
# Kolmogorov-Smirnov Test Statistic = 1.000, p-value = 0.000

# %% [markdown]
# ### Observation Number 7
#
# > The histogram & Kolmogorov-Smirnov test proved (since  the p-value is less than the chosen significance level, usually 0.05) that the data is not normally distributed for the following attributes:
# - Monthly Charges
# - CLTV
# - Tenure_Months
# - Churn_Score

# %% [markdown]
# Based on Observation Number 1, We Can present the information stored in the customer’s current contract type: Month-to-Month, One Year, Two Year as:
#
# - Monthly
# - Annual
# - Biennial

# %%
for i in df.Contract.unique():
    print(i)
# Out:
# Month-to-month
# Two year
# One year

# %%
df["Contract"]=df["Contract"].replace("Month-to-month","Monthly")
df["Contract"]=df["Contract"].replace("One year","Annual")
df["Contract"]=df["Contract"].replace("Two year","Biennial")

# %% [markdown]
# # Question and Aswers :
# > We are going to pose following questions against the dataset:
#
# 1. What percentage of customer has left the company in Q3?
# 2. What is the Breakdown of churned & retained customers by Gender?
# 3. Does all customers have high churn Score based on Contracts?
# 4. What is the Breakdown of churned customer vs. retained customers based on:
#    1. Contract Type
#    2. Services
#    3. Paperless Billing (yes/no)
#    4. Payment Method
# 5. What are the Top 10 churn Customer Count belongs to which City
# 6. What are the Top 10 churn customer count distribution over zip code in the highest churning city
# 7. What is the churn Ratio of Senior Ciitizen vs. Non Senior Citizen
# 8. What is the churn analysis based on dependent
# 9. What is the churn analysis based on tenure months
# 10. What is the churn analysis based on monthly charges
# 11. What is the Customer Churn Rate?

# %% [markdown]
# Question 1.What percentage of customer has left the company in Q3?

# %%
plt.figure(figsize=(10,5))
plt.pie(df['churn_label'].value_counts(), labels=df['churn_label'].unique(), autopct='%.2f%%')
plt.show()

# %% [markdown]
# > **Figure-8** Pie plot showing percenatge of churn vs. active customers

# %% [markdown]
# Answer 1. Around 27% of customers have left the company due to multiple reasons

# %% [markdown]
# Question 2. What is the Breakdown of churned & retained customers by Gender?

# %%
by_gender = df.groupby('churn_label')['Gender'].value_counts().to_frame().rename(columns={'Gender': 'Freq'}).reset_index().sort_values('churn_label')

# Make data: I have 3 groups and 7 subgroups
group_names=df['churn_label'].value_counts().index
group_size=df['churn_label'].value_counts()
subgroup_names=by_gender['Gender']
subgroup_size=by_gender['Freq']
 
# Create colors
a, b =[plt.cm.Blues, plt.cm.Reds]
 
# First Ring (outside)
fig, ax = plt.subplots()
fig.suptitle('Churn Distribution By Gender')
ax.axis('equal')
mypie, _ = ax.pie(group_size, radius=1.3, labels=group_names, colors=[a(0.6), b(0.6)])
plt.setp( mypie, width=0.3, edgecolor='white')
 
# Second Ring (Inside)
mypie2, _ = ax.pie(subgroup_size, radius=1.3-0.3, labels=subgroup_names, labeldistance=0.7, colors=[a(0.5), a(0.4), b(0.5), b(0.4)])
plt.setp( mypie2, width=0.4, edgecolor='white')
plt.margins(0,0)
 
# show it
plt.show()

# %% [markdown]
# > **Figure-9** Pie plot showing percenatge of churn distribution by gender

# %% [markdown]
# Answer 2. Based on the visualization, it appears that the proportions of males and females who churn or remain customers is almost equal

# %% [markdown]
# Question 3. Does all customers have high churn Score based on Contracts?

# %%
plt.figure(figsize=(20,9))
plt.xticks(rotation=90,fontsize=10)
plt.xlabel("churn_label")
plt.ylabel("churn_score")
plt.title("Customers (Churn vs. Retain) - Churn Score")
sns.barplot(x = df['churn_label'], y = df['churn_score'], hue=df['Contract'])
# Out:
# <AxesSubplot: title={'center': 'Customers (Churn vs. Retain) - Churn Score'}, xlabel='churn_label', ylabel='churn_score'>

# %% [markdown]
# > **Figure-10** Churn Score mapping of Customers based on their billing cycle

# %% [markdown]
# Answer 3. Yes, its true. Plus the plot also shows that the churn frequency or rate of churn is eqully distrubuted across all three billing cycles

# %% [markdown]
# Question 4. What is the Breakdown of churned customer vs. retained customers based on:
#    1. Contract Type
#    2. Services
#    3. Paperless Billing (yes/no)
#    4. Payment Method

# %%
## Breakdown of churned customer vs. retained customers based on:  Contract Type
cnt_Churn_Cntrct = df.groupby(['churn_label', 'Contract']).size().reset_index(name='Count')
cnt_Churn_Cntrct.groupby(['churn_label', 'Contract'])['Count'].sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: xlabel='churn_label'>

# %% [markdown]
# > **Figure-11** Churn vs. Retain customers count based on billing cycle

# %% [markdown]
# Answer 4.1: The plot shows that the Churn customer is mainly from monthly billing cycle caetegory

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip_Code',
#        'Latitude', 'Longitude', 'Gender', 'Senior_Citizen', 'Partner',
#        'Dependents', 'Tenure_Months', 'Phone_Service', 'Multiple_Lines',
#        'Internet_Service', 'Online_Security', 'Online_Backup',
#        'Device_Protection', 'Tech_Support', 'Streaming_TV', 'Streaming_Movies',
#        'Contract', 'Paperless_Billing', 'Payment_Method', 'Monthly_Charges',
#        'Total_Charges', 'Churn_Label', 'Churn_Score', 'CLTV'],
#       dtype='object')

# %%
#Breakdown of churned customer vs. retained customers based on: Services Phone_Service
cnt_Churn_Cntrct = df.groupby(['churn_label', 'phone_service']).size().reset_index(name='Count')
cnt_Churn_Cntrct.groupby(['churn_label', 'phone_service'])['Count'].sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: xlabel='churn_label'>

# %% [markdown]
# > **Figure-11A** Breakdown of churned customer vs. retained customers based on:  Phone_Service

# %%
#Breakdown of churned customer vs. retained customers based on: Multiple_Lines
cnt_Churn_Cntrct = df.groupby(['churn_label', 'multiple_lines']).size().reset_index(name='Count')
cnt_Churn_Cntrct.groupby(['churn_label', 'multiple_lines'])['Count'].sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: xlabel='churn_label'>

# %% [markdown]
# > **Figure-11B** Breakdown of churned customer vs. retained customers based on: Multiple Lines

# %%
#Breakdown of churned customer vs. retained customers based on: Internet_Service
cnt_Churn_Cntrct = df.groupby(['churn_label', 'internet_service']).size().reset_index(name='Count')
cnt_Churn_Cntrct.groupby(['churn_label', 'internet_service'])['Count'].sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: xlabel='churn_label'>

# %% [markdown]
# > **Figure-11C** Breakdown of churned customer vs. retained customers based on: Internet_Service

# %%
#Breakdown of churned customer vs. retained customers based on: Online_Security
cnt_Churn_Cntrct = df.groupby(['churn_label', 'online_security']).size().reset_index(name='Count')
cnt_Churn_Cntrct.groupby(['churn_label', 'online_security'])['Count'].sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: xlabel='churn_label'>

# %% [markdown]
# > **Figure-11D** Breakdown of churned customer vs. retained customers based on: Online_Security

# %%
#Breakdown of churned customer vs. retained customers based on: Online_Backup
cnt_Churn_Cntrct = df.groupby(['churn_label', 'online_backup']).size().reset_index(name='Count')
cnt_Churn_Cntrct.groupby(['churn_label', 'online_backup'])['Count'].sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: xlabel='churn_label'>

# %% [markdown]
# > **Figure-11E** Breakdown of churned customer vs. retained customers based on: Online_Backup

# %%
#Breakdown of churned customer vs. retained customers based on: Device_Protection
cnt_Churn_Cntrct = df.groupby(['churn_label', 'device_protection']).size().reset_index(name='Count')
cnt_Churn_Cntrct.groupby(['churn_label', 'device_protection'])['Count'].sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: xlabel='churn_label'>

# %% [markdown]
# > **Figure-11F** Breakdown of churned customer vs. retained customers based on: Device_Protection

# %%
#Breakdown of churned customer vs. retained customers based on: Tech_Support
cnt_Churn_Cntrct = df.groupby(['churn_label', 'tech_support']).size().reset_index(name='Count')
cnt_Churn_Cntrct.groupby(['churn_label', 'tech_support'])['Count'].sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: xlabel='churn_label'>

# %% [markdown]
# > **Figure-11G** Breakdown of churned customer vs. retained customers based on: Tech_Support

# %%
#Breakdown of churned customer vs. retained customers based on: Streaming_TV
cnt_Churn_Cntrct = df.groupby(['churn_label', 'streaming_tv']).size().reset_index(name='Count')
cnt_Churn_Cntrct.groupby(['churn_label', 'streaming_tv'])['Count'].sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: xlabel='churn_label'>

# %% [markdown]
# > **Figure-11H** Breakdown of churned customer vs. retained customers based on: Streaming_TV

# %%
#Breakdown of churned customer vs. retained customers based on: Streaming_Movies
cnt_Churn_Cntrct = df.groupby(['churn_label', 'streaming_movies']).size().reset_index(name='Count')
cnt_Churn_Cntrct.groupby(['churn_label', 'streaming_movies'])['Count'].sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: xlabel='churn_label'>

# %% [markdown]
# > **Figure-11I** Breakdown of churned customer vs. retained customers based on: Streaming_Movies

# %% [markdown]
# Answer 4.2:
# - The plot shows that the Churn customer using phone services has more churn rate
# - Multiple Lines: Both retain and churn customers have equal distribution. However customers without multiple lines churned partially more than with multiple lines
# - Customers using Fiber Optics have more churning ration than other internet services
# - Customers without the option of Online_Security churns more
# - Customers without the option of Online_Backup churns more
# - Customers without the option of Device_Protection churns more
# - Customers without the option of Tech_Support churns more
# - Customers without Streaming_TV services churned partially more than with multiple lines
# - Customers without Streaming_Movies services churned partially more than with multiple lines

# %% [markdown]
# Question 5. What are the Top 10 churn Customer Count belongs to which City

# %%
# Filter the dataset by churn_label='Yes' and select the 'State' column
churn_yes_states = df.loc[df['churn_label'] == 'Yes', 'City']

# Get the value counts of each state
state_counts = churn_yes_states.value_counts().nlargest(10)

# Create a horizontal bar plot
plt.barh(state_counts.index, state_counts.values)

# Set plot title and axis labels
plt.title('Churned Customers by City')
plt.xlabel('Number of Churned Customers')
plt.ylabel('City')

# Display the plot
plt.show()

# %% [markdown]
# > **Figure-12A** Top 10 Churn Customer count breakdown in cities

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip_Code',
#        'Latitude', 'Longitude', 'Gender', 'Senior_Citizen', 'Partner',
#        'Dependents', 'Tenure_Months', 'Phone_Service', 'Multiple_Lines',
#        'Internet_Service', 'Online_Security', 'Online_Backup',
#        'Device_Protection', 'Tech_Support', 'Streaming_TV', 'Streaming_Movies',
#        'Contract', 'Paperless_Billing', 'Payment_Method', 'Monthly_Charges',
#        'Total_Charges', 'Churn_Label', 'Churn_Score', 'CLTV'],
#       dtype='object')

# %% [markdown]
# ### Geo spatial view of the Lat Long coordinates

# %%
churned_df = df.loc[df['churn_label'] == 'Yes']
churn_yes_LatLong = churned_df[["Latitude", "Longitude", "City"]]
# Create map object
m = folium.Map(location=[churn_yes_LatLong['Latitude'].mean(), churn_yes_LatLong['Longitude'].mean()], zoom_start=8)

# Add markers for each point in the dataset
for index, row in churn_yes_LatLong.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup=row['City']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# > **Figure-12B** Plot to show geo spatial view of churn customers

# %% [markdown]
# Answer 5.
# Based on the dataset, it was found that the maximum number of churned customers is from Los Angeles, with a total of 90 customers. This indicates that the company should investigate the reasons behind the high churn rate in this location and take appropriate measures to address them

# %% [markdown]
# Question 6.  What are the Top 10 churn customer count distribution over zip code in the highest churning city?

# %%
# Filter the dataset by churn_label='Yes' and select the 'State' column
churn_yes_states = df.loc[(df['churn_label'] == 'Yes') & (df['City'] == 'Los Angeles'), 'zip_code']


# Get the value counts of each state
LAZipCnt = churn_yes_states.value_counts().nlargest(10)

# Create a horizontal bar plot
plt.barh(LAZipCnt.index, state_counts.values)

# Set plot title and axis labels
plt.title('Top 10 Churned Customers Count in LA by Zip_Code')
plt.xlabel('Number of Churned Customers')
plt.ylabel('LA Zip_Code')

# Display the plot
plt.show()

# %% [markdown]
# > **Figure-12** Top 10 Churned Customers Count in LA by Zip_Code

# %% [markdown]
# Answer 6. 90020 is the post code in LA with maximum number of churns reported

# %% [markdown]
# Question 7. What is the churn Ratio of Senior Ciitizen vs. Non Senior Citizen?

# %%
sns.catplot(x='Gender', hue='churn_label', col='senior_citizen', kind='count', data=df)

# %% [markdown]
# > **Figure-13** Ratio of Senior Citizen vs. Non Senior Citizen

# %% [markdown]
# Answer 7. From the visualization above, we can see that the churn and retain ratio for senior citizens vs. non seniors is almost same

# %% [markdown]
# Question 8. What is the churn analysis based on dependent?

# %%
sns.catplot(x='Gender', hue='churn_label', col='Dependents', kind='count', data=df)

# %% [markdown]
# > **Figure-14** Churn analysis based on dependent

# %%
sns.catplot(x='Gender', hue='churn_label', col='Partner', kind='count', data=df)

# %% [markdown]
# > **Figure-15** Churn analysis based on Partner

# %% [markdown]
# Answer 8.
# - Figure 14: Shows that Males with dependents are churning less than females. However customers without dependents have higher churn values
# - Figure 15: Customers with partners has lower churn chances than the customers without partners

# %% [markdown]
# Question 9. What is the churn analysis based on tenure months?

# %%
plt.figure(figsize=(15,10))
plt.title('Tenure (Months) distribution')
sns.histplot(df[df['churn_label'] == 'Yes']['tenure_months'], label='Churn', kde = 1)
sns.histplot(df[df['churn_label'] == 'No']['tenure_months'], label='Retain', kde = 1)
plt.legend(loc= 'upper right')
plt.show()

# %% [markdown]
# > **Figure-16** Churn analysis based on tenure months is shown in the Tenure Month Distribution Plot

# %% [markdown]
# Answer 9. We can see that, the longer a customer uses the provider, the probability of churn decreases.

# %% [markdown]
# Question 10.  What is the churn analysis based on monthly charges?

# %%
plt.figure(figsize=(15,10))
plt.title('Monthly_Charges distribution')
sns.histplot(df[df['churn_label'] == 'Yes']['monthly_charges'], label='Churn', kde = 1)
sns.histplot(df[df['churn_label'] == 'No']['monthly_charges'], label='Retain', kde = 1)
plt.legend(loc= 'upper right')
plt.show()

# %% [markdown]
# > **Figure-17** Churn analysis based on monthly charges is shown in the Monthly Charges Plot

# %% [markdown]
# Answer 10.  Customer making transactions per month on average more than $ 60, are more likely to churn than the average transaction below that

# %% [markdown]
# Question 11. What is the Customer Churn Rate?
#
# Formula: Customer Churn Rate=(No. Of customers churned in a period/No. Of customers at the beginning of period)*100

# %%
#Get the total count of Customer
customer_count = len(df['CustomerID'].unique())

print(f"Total number of customers: {customer_count}")

# Filter the dataset by the churned condition
filtered_dataset = df[df['churn_label'] == 'Yes']

# Find the count of unique customer IDs in the filtered dataset
churn_customer_count = filtered_dataset['CustomerID'].nunique()

print(f"Total number of customers where churn condition is true: {churn_customer_count}")

# Applying Churn rate formula
CCR = (churn_customer_count/customer_count)*100

print(f"Customer Churn Rate: {CCR}")
# Out:
# Total number of customers: 7043
# Total number of customers where churn condition is true: 1869
# Customer Churn Rate: 26.536987079369588

# %% [markdown]
# # Summary
#
# Q1. What percentage of customer has left the company in Q3 (Quarter-3)?\
# A1. Around 27% of customers have left the company due to multiple reasons during Q3. We have addresses this mathematically in Q11
#
# Q2. What is the Breakdown of churned & retained customers by Gender?\
# A2. Based on the visualization, it appears that the proportions of males and females who churn or remain customers is almost equal
#
# Q3. Does all customers have high churn Score based on Contracts?\
# A3. That is correct. Moreover, the plot reveals that the frequency of churn, or churn rate, is evenly distributed across all three billing cycles
#
# Q4. What is the Breakdown of churned customer vs. retained customers based on:
#    1. Contract Type
#    2. Services
#    3. Paperless Billing (yes/no)
#    4. Payment Method
# A4.
# The plot indicates that the majority of churned customers are on the monthly billing cycle.
# Customers who use phone services have a higher churn rate compared to those who do not.
# For customers with and without multiple lines, the distribution of churn and retention is relatively equal, but those without multiple lines experience slightly higher churn rates.
# Customers who use Fiber Optic internet services have a higher churn rate compared to other types of internet services.
# Customers without Online Security, Online Backup, Device Protection, and Tech Support options have higher churn rates.
# Customers without Streaming TV and Streaming Movies services have slightly higher churn rates compared to those with these services.
#
#
# Q5. What are the Top 10 churn Customer Count belongs to which City?\
# A5. Based on the dataset, it was found that the maximum number of churned customers is from Los Angeles, with a total of 90 customers. This indicates that the company should investigate the reasons behind the high churn rate in this location and take appropriate measures to address them
#
# Q6. What are the Top 10 churn customer count distribution over zip code in the highest churning city?\
# A6. ZIP Code 90020 is the post code in LA with maximum number of churns reported
#
# Q7.  What is the churn Ratio of Senior Ciitizen vs. Non Senior Citizen?\
# A7. Its observed that the proportion of churn and retain customers among senior citizens and non-senior citizens is nearly equal.
#
# Q8. What is the churn analysis based on dependent?\
# A8. According to Figure 14, the data indicates that female customers without dependents are more likely to churn than male customers with dependents. In other words, having dependents seems to reduce the churn rate for male customers, while not having dependents increases the churn rate for female customers.
# The findings in Figure 15 suggest that customers with partners are less likely to churn than customers without partners. This implies that having a partner may be a factor that contributes to customer retention in the telecommunications industry.
#
# Q9. What is the churn analysis based on tenure months?\
# A9. We can see that, the longer a customer uses the provider, the probability of churn decreases.
#
# Q10.   What is the churn analysis based on monthly charges\
# A10.  Customer making transactions per month on average more than $ 60, are more likely to churn than the average transaction below that
#
# Q11. What is the Customer Churn Rate?\
# A11. 26.53% is the customer churn rate

# %% [markdown]
# # Conclusion & Findings
#
# Based on the visualizations and data analysis, it is clear that Q3 data has a significant increase in customer churn, especially for customers on the monthly billing cycle and those without certain services such as Online Security, Online Backup, Device Protection, and Tech Support. The company should investigate the reasons behind the high churn rate in Los Angeles, which has the highest number of churned customers. Additionally, having dependents seems to reduce the churn rate for male customers while having a partner may contribute to customer retention. Finally, the longer a customer uses the provider, the lower the probability of churn, and customers with transactions per month averaging over $60 are more likely to churn.

# %% [markdown]
# # Contact Details
# Click on link below to contact/follow/correct me:
#
# [Github](https://github.com/AzamBukhari)\
# [kaggle](https://www.kaggle.com/azambukhari)\
# [Linkedin](https://www.linkedin.com/in/azambukhari)\
# [twitter](https://twitter.com/AzamBukhari1)\
# [Medium](https://medium.com/@azam.bukhari)
#
# ![Telco Customer Churn](churn-rate.png "EDA Customer Churn By Azam  Bukhari")
